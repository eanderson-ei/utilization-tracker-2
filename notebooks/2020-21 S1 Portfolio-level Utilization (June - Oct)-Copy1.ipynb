# %% [markdown]
# # 2020-21 S1 Portfolio-level Utilizations (June - Oct)
# Utilization is calculated at the portfolio level as the total billable hours divided by a weighted FTE based on the proportion of the company's time spent towards that portfolio. Because Deltek was not available in April and May, those hours are dropped from the analysis.
#
# To calculate utilization at the portfolio level, information required includes:
# * **org_bill_hrs**: Total billable hours for the portfolio
# * **org_total_hrs**: Total hours (billable and non-billable) for the portfolio (e.g., Planning & Ops, HR, General)
# * **fte_hrs**: FTE hours for the company (i.e., total workable days * number of employees each day * 8 hours per day)
# * **total_hrs**: Total hours for the company (i.e., total of all hours worked)
#
# This workbook evaluates portfolio-level utilizations without first filtering by team member (i.e., excluding employees that did not log any hours to the portfolio). See *2020-21 S2 Portfolio-level Utilizations (filtered)* for comparison.

# %%
import pandas as pd
import numpy as np

# %%
# read in data
util_df = pd.read_csv(r'C:\Users\Erik\Downloads\Utilization Tabular (12).csv', sep='\t',
                       encoding='utf_16_le')
util_df['Hours Date'] = pd.to_datetime(util_df['Hours Date'])
filt = (util_df['Hours Date'] < pd.to_datetime('2020-10-31')) &  (util_df['Hours Date'] > pd.to_datetime('2020-06-01'))
util_df = util_df[filt]
org_df = pd.read_csv(r'C:\Users\Erik\Downloads\Organizations.csv', sep='\t',
                       encoding='utf_16_le')
emp_df = pd.read_csv(r'C:\Users\Erik\Downloads\Employees (14).csv', sep='\t',
                       encoding='utf_16_le')
emp_df['Hire date'] = pd.to_datetime(emp_df['Hire date'])
emp_df['Termination date'] = pd.to_datetime(emp_df['Termination date'])

# %%
util_df.head()
# Out:
#    Employee ID      Last Name First Name Work Schedule Description  \
# 3     100001.0  Alexandrovich     Andrew                  Standard
# 4     100001.0  Alexandrovich     Andrew                  Standard
# 5     100001.0  Alexandrovich     Andrew                  Standard
# 6     100001.0  Alexandrovich     Andrew                  Standard
# 7     100001.0  Alexandrovich     Andrew                  Standard
#
#          Org Name       Project ID               Project Name  \
# 3  Company Health  INDR.001.001.01  Planning and Ops Gen Intl
# 4  Company Health  INDR.001.009.01        Planning and Ops CH
# 5  Company Health  INDR.001.009.01        Planning and Ops CH
# 6  Company Health  INDR.002.009.01         HR & Recruiting CH
# 7  Company Health  INDR.005.001.01           R&D General Intl
#
#   User Defined Code 3 Hours Date  Entered Hours  Approved Hours Comments
# 3                 OVH 2020-06-02           1.50               0      NaN
# 4                 G&A 2020-06-02           7.50               0      NaN
# 5                 G&A 2020-06-03           5.86               0      NaN
# 6                 G&A 2020-06-03           5.00               0      NaN
# 7                 IRD 2020-06-03           1.67               0      NaN

# %%
org_df.head()
# Out:
#         Project ID               Project Name Organization ID  \
# 0             1001  USAID Measuring Impact II      1.01.01.01
# 1         1001.AFR                     BI-AFR      1.01.01.04
# 2     1001.AFR.001                     BI-AFR      1.01.01.04
# 3  1001.AFR.001.01        16.0.AFR_BuyIn_Mgmt      1.01.01.04
# 4  1001.AFR.001.02        16.0.AFR_Zambia FS       1.01.01.04
#
#   Organization Name  Level Number
# 0      General Intl             4
# 1            Africa             4
# 2            Africa             4
# 3            Africa             4
# 4            Africa             4

# %%
# confirm Project ID is unique
len(org_df) == len(org_df['Project ID'].unique())
# Out:
# True

# %%
# merge hours entries and organizations
df = pd.merge(util_df, org_df, how='left', left_on='Project ID', right_on='Project ID')
df['Project Name'] = df['Project Name_x']
df = df.drop(columns=['Project Name_x', 'Project Name_y'])
df.head()
# Out:
#    Employee ID      Last Name First Name Work Schedule Description  \
# 0     100001.0  Alexandrovich     Andrew                  Standard
# 1     100001.0  Alexandrovich     Andrew                  Standard
# 2     100001.0  Alexandrovich     Andrew                  Standard
# 3     100001.0  Alexandrovich     Andrew                  Standard
# 4     100001.0  Alexandrovich     Andrew                  Standard
#
#          Org Name       Project ID User Defined Code 3 Hours Date  \
# 0  Company Health  INDR.001.001.01                 OVH 2020-06-02
# 1  Company Health  INDR.001.009.01                 G&A 2020-06-02
# 2  Company Health  INDR.001.009.01                 G&A 2020-06-03
# 3  Company Health  INDR.002.009.01                 G&A 2020-06-03
# 4  Company Health  INDR.005.001.01                 IRD 2020-06-03
#
#    Entered Hours  Approved Hours Comments Organization ID  Organization Name  \
# 0           1.50               0      NaN      1.01.01.01       General Intl
# 1           7.50               0      NaN      1.01.90.01  HR and Operations
# 2           5.86               0      NaN      1.01.90.01  HR and Operations
# 3           5.00               0      NaN      1.01.90.01  HR and Operations
# 4           1.67               0      NaN      1.01.01.01       General Intl
#
#    Level Number               Project Name
# 0             4  Planning and Ops Gen Intl
# 1             4        Planning and Ops CH
# 2             4        Planning and Ops CH
# 3             4         HR & Recruiting CH
# 4             4           R&D General Intl

# %%
# confirm |merge did not add new time entries
len(util_df) - len(df) == 0
# Out:
# True

# %%
df.columns
# Out:
# Index(['Employee ID', 'Last Name', 'First Name', 'Work Schedule Description',
#        'Org Name', 'Project ID', 'User Defined Code 3', 'Hours Date',
#        'Entered Hours', 'Approved Hours', 'Comments', 'Organization ID',
#        'Organization Name', 'Level Number', 'Project Name'],
#       dtype='object')

# %%
df['Organization Name'].unique()
# Out:
# array(['General Intl', 'HR and Operations', 'Global Adaptive Managemen',
#        'Latin America & the Carib', 'General Domestic',
#        'Environmental Incentives', 'Comms & KM', 'HR & Ops General',
#        'Contract&Fin Spec Initiat', 'HR & Ops Special Initiat', 'Water',
#        'Africa', 'Habitat', 'Marketing General'], dtype=object)

# %%
# check for null organizations
filt = df['Organization Name'].isnull()
no_org_df = df.loc[filt]
no_org_df['Project Name'].unique()
# Out:
# array([], dtype=object)

# %%
no_org_df['Entered Hours'].sum()
# Out:
# 0.0

# %%
emp_df.head()
# Out:
#    Employee ID      Last Name   First Name Middle Initial  \
# 0       100041        Abragan  Maria Celes              L
# 1       100003         Ajroud     Brittany              N
# 2       100001  Alexandrovich       Andrew            NaN
# 3       100022       Anderson         Erik              T
# 4       100027       Armanino        Molly            NaN
#
#                    E-mail Address Active Flag  Hire date Termination date  \
# 0   mabragan@enviroincentives.com           Y 2019-04-08              NaT
# 1    bajroud@enviroincentives.com           Y 2016-10-18              NaT
# 2     andrew@enviroincentives.com           Y 2010-04-05              NaT
# 3  eanderson@enviroincentives.com           Y 2014-03-17              NaT
# 4  marmanino@enviroincentives.com           N 2017-06-18       2019-12-14
#
#   Work Schedule Work Schedule Description Default Org
# 0           STD                  Standard     1.01.01
# 1           STD                  Standard     1.01.01
# 2           STD                  Standard     1.01.90
# 3           STD                  Standard     1.01.02
# 4           NaN                       NaN         NaN

# %% [markdown]
# ## fte_hrs

# %%
def get_bus_hrs(emp_df, start, end):
    """start and end as 'YYYY-MM-DD' strings"""
    start = pd.to_datetime(start)
    end = pd.to_datetime(end)
    
    fte_df = emp_df[['Employee ID', 'Hire date', 'Termination date']].copy()

    def update_start(hire_date):
        if hire_date < sem_start:
            return sem_start
        elif hire_date > sem_end:
            return sem_end
        else:
            return hire_date

    def update_end(termination_date):
        if pd.isnull(termination_date):
            return sem_end
        if termination_date > sem_end:
            return sem_end
        elif termination_date < sem_start:
            return sem_start
        else:
            return termination_date

    fte_df['sem_start'] = fte_df['Hire date'].apply(update_start)
    fte_df['sem_end'] = fte_df['Termination date'].apply(update_end)
    fte_df['bushrs'] = np.busday_count(fte_df['sem_start'].dt.date, fte_df['sem_end'].dt.date) * 8
    
    fte_hrs = fte_df['bushrs'].sum()
    
    return fte_hrs

# %%
# fte hours is total number of fte days by start and end dates (ignore part time and very part time (e.g., CB))
sem_start = pd.to_datetime('2020-06-01')
sem_end = pd.to_datetime('2020-10-31')

fte_df = emp_df[['Employee ID', 'Hire date', 'Termination date']].copy()

def update_start(hire_date):
    if hire_date < sem_start:
        return sem_start
    elif hire_date > sem_end:
        return sem_end
    else:
        return hire_date
    
def update_end(termination_date):
    if pd.isnull(termination_date):
        return sem_end
    if termination_date > sem_end:
        return sem_end
    elif termination_date < sem_start:
        return sem_start
    else:
        return termination_date

fte_df['sem_start'] = fte_df['Hire date'].apply(update_start)
fte_df['sem_end'] = fte_df['Termination date'].apply(update_end)
fte_df['bushrs'] = np.busday_count(fte_df['sem_start'].dt.date, fte_df['sem_end'].dt.date) * 8

fte_df.head()
# Out:
#    Employee ID  Hire date Termination date  sem_start    sem_end  bushrs
# 0       100041 2019-04-08              NaT 2020-06-01 2020-10-31     880
# 1       100003 2016-10-18              NaT 2020-06-01 2020-10-31     880
# 2       100001 2010-04-05              NaT 2020-06-01 2020-10-31     880
# 3       100022 2014-03-17              NaT 2020-06-01 2020-10-31     880
# 4       100027 2017-06-18       2019-12-14 2020-06-01 2020-06-01       0

# %%
fte_hrs = get_bus_hrs(emp_df, '2020-06-01', '2020-10-31')
fte_hrs
# Out:
# 50400

# %%
fte_hrs = fte_df['bushrs'].sum()
fte_hrs
# Out:
# 50400

# %% [markdown]
# ## total_hrs

# %%
def get_total_hrs(df, start, end):
    """start and end as 'YYYY-MM-DD' strings"""
    start = pd.to_datetime(start)
    end = pd.to_datetime(end)
    
    filt = (df['Hours Date'] >= start) & (df['Hours Date'] <= end)
    df = df.loc[filt]
    
    total_hrs = df['Entered Hours'].sum()
    
    return total_hrs

# %%
total_hrs = get_total_hrs(df, '2020-06-01', '2020-10-31')
total_hrs
# Out:
# 47402.560000000005

# %%
# total hours is straight sum 
total_hrs = df['Entered Hours'].sum()
total_hrs
# Out:
# 47402.560000000005

# %%
# the proportion of total hours worked is slightly less than full time, consistent with some employees being part time
total_hrs/fte_hrs
# Out:
# 0.9405269841269842

# %%
# review fte by employee based on expected fte hours as calculated
hrs_by_emp = df.groupby('Employee ID').sum()['Entered Hours']
hrs_by_emp = pd.merge(hrs_by_emp, fte_df, left_index=True, right_on='Employee ID', how='left')
hrs_by_emp['fte'] = hrs_by_emp['Entered Hours'] / hrs_by_emp['bushrs']
hrs_by_emp = pd.merge(hrs_by_emp, emp_df, on='Employee ID')
hrs_by_emp.loc[:, ['Last Name', 'First Name', 'Entered Hours', 'sem_start', 'sem_end', 'bushrs', 'fte']].sort_values('fte', ascending=False)
# Out:
#    Last Name First Name  Entered Hours  sem_start    sem_end  bushrs       fte
# 64   Byenkya       Tina         296.00 2020-10-02 2020-10-31     168  1.761905
# 62     Owusu     Philip         364.00 2020-09-15 2020-10-31     272  1.338235
# 63    Walter      Karen         286.50 2020-09-22 2020-10-31     232  1.234914
# 13      Hoye      Susan        1062.80 2020-06-01 2020-10-31     880  1.207727
# 34      Shay      Arica        1036.07 2020-06-01 2020-10-31     880  1.177352
# ..       ...        ...            ...        ...        ...     ...       ...
# 31    Exline      Kelly         779.10 2020-06-01 2020-10-31     880  0.885341
# 5     Flower   Kathleen         713.12 2020-06-01 2020-10-31     880  0.810364
# 27     Brock    Cameryn         625.98 2020-06-15 2020-10-31     800  0.782475
# 4     Dubois    Natalie         651.00 2020-06-01 2020-10-31     880  0.739773
# 3       Cook   Caroline         262.40 2020-06-01 2020-10-31     880  0.298182
#
# [68 rows x 7 columns]

# %%
# what is happening with high ftes for some new employees?
filt = df['Last Name'].isin(['Byenkya'])
df[filt]
# Out:
#        Employee ID Last Name First Name Work Schedule Description Org Name  \
# 22022     100097.0   Byenkya       Tina            Standard Kenya   Africa
# 22023     100097.0   Byenkya       Tina            Standard Kenya   Africa
# 22024     100097.0   Byenkya       Tina            Standard Kenya   Africa
# 22025     100097.0   Byenkya       Tina            Standard Kenya   Africa
# 22026     100097.0   Byenkya       Tina            Standard Kenya   Africa
# 22027     100097.0   Byenkya       Tina            Standard Kenya   Africa
# 22028     100097.0   Byenkya       Tina            Standard Kenya   Africa
# 22029     100097.0   Byenkya       Tina            Standard Kenya   Africa
# 22030     100097.0   Byenkya       Tina            Standard Kenya   Africa
# 22031     100097.0   Byenkya       Tina            Standard Kenya   Africa
# 22032     100097.0   Byenkya       Tina            Standard Kenya   Africa
# 22033     100097.0   Byenkya       Tina            Standard Kenya   Africa
# 22034     100097.0   Byenkya       Tina            Standard Kenya   Africa
# 22035     100097.0   Byenkya       Tina            Standard Kenya   Africa
# 22036     100097.0   Byenkya       Tina            Standard Kenya   Africa
# 22037     100097.0   Byenkya       Tina            Standard Kenya   Africa
# 22038     100097.0   Byenkya       Tina            Standard Kenya   Africa
# 22039     100097.0   Byenkya       Tina            Standard Kenya   Africa
# 22040     100097.0   Byenkya       Tina            Standard Kenya   Africa
# 22041     100097.0   Byenkya       Tina            Standard Kenya   Africa
# 22042     100097.0   Byenkya       Tina            Standard Kenya   Africa
# 22043     100097.0   Byenkya       Tina            Standard Kenya   Africa
# 22044     100097.0   Byenkya       Tina            Standard Kenya   Africa
# 22045     100097.0   Byenkya       Tina            Standard Kenya   Africa
# 22046     100097.0   Byenkya       Tina            Standard Kenya   Africa
# 22047     100097.0   Byenkya       Tina            Standard Kenya   Africa
# 22048     100097.0   Byenkya       Tina            Standard Kenya   Africa
# 22049     100097.0   Byenkya       Tina            Standard Kenya   Africa
#
#             Project ID User Defined Code 3 Hours Date  Entered Hours  \
# 22022  1009.003.202.01                 SRV 2020-10-02           16.0
# 22023  1009.003.202.01                 SRV 2020-10-05           16.0
# 22024  1009.003.202.01                 SRV 2020-10-06           16.0
# 22025  1009.003.202.01                 SRV 2020-10-07           16.0
# 22026  1009.003.202.01                 SRV 2020-10-08           16.0
# 22027  1009.003.202.01                 SRV 2020-10-09           16.0
# 22028  1009.003.202.01                 SRV 2020-10-12            8.0
# 22029  1009.003.202.01                 SRV 2020-10-12            8.0
# 22030  1009.003.202.01                 SRV 2020-10-13           16.0
# 22031  1009.003.202.01                 SRV 2020-10-14           16.0
# 22032  1009.003.202.01                 SRV 2020-10-15           16.0
# 22033  1009.003.202.01                 SRV 2020-10-16            8.0
# 22034  1009.003.202.01                 SRV 2020-10-16            8.0
# 22035  1009.003.202.01                 SRV 2020-10-19            8.0
# 22036  1009.003.202.01                 SRV 2020-10-19            8.0
# 22037  1009.003.202.01                 SRV 2020-10-20            8.0
# 22038  1009.003.202.01                 SRV 2020-10-20            8.0
# 22039  1009.003.202.01                 SRV 2020-10-21            8.0
# 22040  1009.003.202.01                 SRV 2020-10-21            8.0
# 22041  1009.003.202.01                 SRV 2020-10-22            8.0
# 22042  1009.003.202.01                 SRV 2020-10-22            8.0
# 22043  1009.003.202.01                 SRV 2020-10-23            8.0
# 22044  1009.003.202.01                 SRV 2020-10-23            8.0
# 22045         INDR.023                 LWP 2020-10-26            8.0
# 22046         INDR.023                 LWP 2020-10-27            8.0
# 22047         INDR.023                 LWP 2020-10-28            8.0
# 22048         INDR.023                 LWP 2020-10-29            8.0
# 22049         INDR.023                 LWP 2020-10-30            8.0
#
#        Approved Hours                                           Comments  \
# 22022               0      Adding time after getting access to timesheet
# 22023               0      Adding time after getting access to timesheet
# 22024               0      Adding time after getting access to timesheet
# 22025               0      Adding time after getting access to timesheet
# 22026               0      Adding time after getting access to timesheet
# 22027               0      Adding time after getting access to timesheet
# 22028               0      Adding time after getting access to timesheet
# 22029               0  I worked on this day. Based on guidance from A...
# 22030               0      Adding time after getting access to timesheet
# 22031               0      Adding time after getting access to timesheet
# 22032               0      Adding time after getting access to timesheet
# 22033               0                                                NaN
# 22034               0                                     Inputting time
# 22035               0                                                NaN
# 22036               0                                     Inputting time
# 22037               0                                                NaN
# 22038               0                                     Inputting time
# 22039               0                                                NaN
# 22040               0                               Inputting daily time
# 22041               0                                                NaN
# 22042               0                               Inputting daily time
# 22043               0                                                NaN
# 22044               0                                     Inputting time
# 22045               0                                                NaN
# 22046               0                                                NaN
# 22047               0                                                NaN
# 22048               0                                                NaN
# 22049               0                                                NaN
#
#       Organization ID          Organization Name  Level Number  \
# 22022      1.01.01.02  Global Adaptive Managemen             4
# 22023      1.01.01.02  Global Adaptive Managemen             4
# 22024      1.01.01.02  Global Adaptive Managemen             4
# 22025      1.01.01.02  Global Adaptive Managemen             4
# 22026      1.01.01.02  Global Adaptive Managemen             4
# 22027      1.01.01.02  Global Adaptive Managemen             4
# 22028      1.01.01.02  Global Adaptive Managemen             4
# 22029      1.01.01.02  Global Adaptive Managemen             4
# 22030      1.01.01.02  Global Adaptive Managemen             4
# 22031      1.01.01.02  Global Adaptive Managemen             4
# 22032      1.01.01.02  Global Adaptive Managemen             4
# 22033      1.01.01.02  Global Adaptive Managemen             4
# 22034      1.01.01.02  Global Adaptive Managemen             4
# 22035      1.01.01.02  Global Adaptive Managemen             4
# 22036      1.01.01.02  Global Adaptive Managemen             4
# 22037      1.01.01.02  Global Adaptive Managemen             4
# 22038      1.01.01.02  Global Adaptive Managemen             4
# 22039      1.01.01.02  Global Adaptive Managemen             4
# 22040      1.01.01.02  Global Adaptive Managemen             4
# 22041      1.01.01.02  Global Adaptive Managemen             4
# 22042      1.01.01.02  Global Adaptive Managemen             4
# 22043      1.01.01.02  Global Adaptive Managemen             4
# 22044      1.01.01.02  Global Adaptive Managemen             4
# 22045            1.01   Environmental Incentives             2
# 22046            1.01   Environmental Incentives             2
# 22047            1.01   Environmental Incentives             2
# 22048            1.01   Environmental Incentives             2
# 22049            1.01   Environmental Incentives             2
#
#             Project Name
# 22022    Somalia Program
# 22023    Somalia Program
# 22024    Somalia Program
# 22025    Somalia Program
# 22026    Somalia Program
# 22027    Somalia Program
# 22028    Somalia Program
# 22029    Somalia Program
# 22030    Somalia Program
# 22031    Somalia Program
# 22032    Somalia Program
# 22033    Somalia Program
# 22034    Somalia Program
# 22035    Somalia Program
# 22036    Somalia Program
# 22037    Somalia Program
# 22038    Somalia Program
# 22039    Somalia Program
# 22040    Somalia Program
# 22041    Somalia Program
# 22042    Somalia Program
# 22043    Somalia Program
# 22044    Somalia Program
# 22045  Leave without Pay
# 22046  Leave without Pay
# 22047  Leave without Pay
# 22048  Leave without Pay
# 22049  Leave without Pay

# %%
# drop Byenkya due to irregularities in data entries (too many 16 hour days)
df = df[~filt]
df
# Out:
#        Employee ID      Last Name First Name Work Schedule Description  \
# 0         100001.0  Alexandrovich     Andrew                  Standard
# 1         100001.0  Alexandrovich     Andrew                  Standard
# 2         100001.0  Alexandrovich     Andrew                  Standard
# 3         100001.0  Alexandrovich     Andrew                  Standard
# 4         100001.0  Alexandrovich     Andrew                  Standard
# ...            ...            ...        ...                       ...
# 22100     100098.0       Richards     Anjali                  Standard
# 22101     100099.0          Myers    Tiffany                  Standard
# 22102     100099.0          Myers    Tiffany                  Standard
# 22103     100100.0      Kapikinyu      Takah                  Standard
# 22104     100100.0      Kapikinyu      Takah                  Standard
#
#                         Org Name       Project ID User Defined Code 3  \
# 0                 Company Health  INDR.001.001.01                 OVH
# 1                 Company Health  INDR.001.009.01                 G&A
# 2                 Company Health  INDR.001.009.01                 G&A
# 3                 Company Health  INDR.002.009.01                 G&A
# 4                 Company Health  INDR.005.001.01                 IRD
# ...                          ...              ...                 ...
# 22100  Global Adaptive Managemen  1009.002.108.02                 SRV
# 22101  Global Adaptive Managemen  1009.002.101.01                 SRV
# 22102  Global Adaptive Managemen  INDR.002.001.02                 OVH
# 22103  Global Adaptive Managemen  1009.002.111.02                 SRV
# 22104  Global Adaptive Managemen  INDR.002.001.02                 OVH
#
#       Hours Date  Entered Hours  Approved Hours               Comments  \
# 0     2020-06-02           1.50               0                    NaN
# 1     2020-06-02           7.50               0                    NaN
# 2     2020-06-03           5.86               0                    NaN
# 3     2020-06-03           5.00               0                    NaN
# 4     2020-06-03           1.67               0                    NaN
# ...          ...            ...             ...                    ...
# 22100 2020-10-30           5.00               0        Buy-in support.
# 22101 2020-10-30           2.00               0  First day onboarading
# 22102 2020-10-30           6.00               0          HR onboarding
# 22103 2020-10-30           6.00               0             Onboarding
# 22104 2020-10-30           2.00               0            HR Meetings
#
#       Organization ID          Organization Name  Level Number  \
# 0          1.01.01.01               General Intl             4
# 1          1.01.90.01          HR and Operations             4
# 2          1.01.90.01          HR and Operations             4
# 3          1.01.90.01          HR and Operations             4
# 4          1.01.01.01               General Intl             4
# ...               ...                        ...           ...
# 22100      1.01.01.02  Global Adaptive Managemen             4
# 22101      1.01.01.02  Global Adaptive Managemen             4
# 22102      1.01.01.02  Global Adaptive Managemen             4
# 22103      1.01.01.02  Global Adaptive Managemen             4
# 22104      1.01.01.02  Global Adaptive Managemen             4
#
#                     Project Name
# 0      Planning and Ops Gen Intl
# 1            Planning and Ops CH
# 2            Planning and Ops CH
# 3             HR & Recruiting CH
# 4               R&D General Intl
# ...                          ...
# 22100           RFS/C Resilience
# 22101                AFR-SD EGEA
# 22102  HR & Recruiting Global AM
# 22103          BHA/DMEL Division
# 22104  HR & Recruiting Global AM
#
# [22077 rows x 15 columns]

# %% [markdown]
# ## org_total_hrs

# %%
def get_org_total_hrs(df, start, end):
    """start and end as 'YYYY-MM-DD' strings
    returns df"""
    start = pd.to_datetime(start)
    end = pd.to_datetime(end)
    
    filt = (df['Hours Date'] >= start) & (df['Hours Date'] <= end)
    df = df.loc[filt]
    
    org_total_hrs = df.groupby('Organization Name').sum()['Entered Hours']
    
    return org_total_hrs

# %%
# calculate total hours by organization
org_total_hrs = df.groupby('Organization Name').sum()['Entered Hours']
org_total_hrs
# Out:
# Organization Name
# Africa                        2303.25
# Comms & KM                    4623.13
# Contract&Fin Spec Initiat       17.25
# Environmental Incentives      4340.32
# General Domestic               145.47
# General Intl                  3655.95
# Global Adaptive Managemen    12819.33
# HR & Ops General               556.03
# HR & Ops Special Initiat       744.58
# HR and Operations             4034.58
# Habitat                       3631.66
# Latin America & the Carib     6609.16
# Marketing General              340.72
# Water                         3285.13
# Name: Entered Hours, dtype: float64

# %%
org_total_hrs = get_org_total_hrs(df, '2020-06-01', '2020-10-31')
org_total_hrs
# Out:
# Organization Name
# Africa                        2303.25
# Comms & KM                    4623.13
# Contract&Fin Spec Initiat       17.25
# Environmental Incentives      4340.32
# General Domestic               145.47
# General Intl                  3655.95
# Global Adaptive Managemen    12819.33
# HR & Ops General               556.03
# HR & Ops Special Initiat       744.58
# HR and Operations             4034.58
# Habitat                       3631.66
# Latin America & the Carib     6609.16
# Marketing General              340.72
# Water                         3285.13
# Name: Entered Hours, dtype: float64

# %%
org_total_hrs.sum()
# Out:
# 47106.56000000002

# %% [markdown]
# ## org_bill_hrs

# %%
def get_org_bill_hrs(df, start, end):
    """start and end as 'YYYY-MM-DD' strings
    returns df"""
    start = pd.to_datetime(start)
    end = pd.to_datetime(end)
    
    filt = (df['Hours Date'] >= start) & (df['Hours Date'] <= end)
    df = df.loc[filt]
    
    filt = df['User Defined Code 3'] == 'SRV'
    org_bill_hrs = df.loc[filt].groupby('Organization Name').sum()['Entered Hours']
    
    return org_bill_hrs

# %%
# calculate billable hours by organization
filt = df['User Defined Code 3'] == 'SRV'
org_bill_hrs = df.loc[filt].groupby('Organization Name').sum()['Entered Hours']
org_bill_hrs
# Out:
# Organization Name
# Africa                        1719.23
# Comms & KM                    3156.49
# General Intl                   285.14
# Global Adaptive Managemen    11382.23
# Habitat                       2455.95
# Latin America & the Carib     5922.95
# Water                         1853.05
# Name: Entered Hours, dtype: float64

# %%
org_bill_hrs = get_org_bill_hrs(df, '2020-06-01', '2020-10-31')
org_bill_hrs
# Out:
# Organization Name
# Africa                        1719.23
# Comms & KM                    3156.49
# General Intl                   285.14
# Global Adaptive Managemen    11382.23
# Habitat                       2455.95
# Latin America & the Carib     5922.95
# Water                         1853.05
# Name: Entered Hours, dtype: float64

# %%
org_bill_hrs.sum()
# Out:
# 26775.04

# %%
# what is billable in General Intl?
filt = (df['Organization Name'] == 'General Intl') & (df['User Defined Code 3'] == 'SRV')
df.loc[filt, 'Project Name'].unique()
# Out:
# array(['Walton-SLED Phase I (IC)', 'Walton-SLED Phase II (IC)'],
#       dtype=object)

# %%
def create_hrs_df(org_bill_hrs, org_total_hrs, total_hrs, fte_hrs):
    hrs_df = pd.merge(org_bill_hrs, org_total_hrs, left_index=True, right_index=True, suffixes=('_bill', '_total'))
    # divide org total hrs by total hours to get proportion
    hrs_df['prop_to_org'] = hrs_df['Entered Hours_total'] / total_hrs
    # weight fte by prop to org
    hrs_df['weighted_fte'] = hrs_df['prop_to_org'] * fte_hrs
    # utilization is billale hours divided by weighted fte
    hrs_df['utilization'] = hrs_df['Entered Hours_bill'] / hrs_df['weighted_fte']
    
    return hrs_df

# %%
hrs_df = create_hrs_df(org_bill_hrs, org_total_hrs, total_hrs, fte_hrs)
hrs_df
# Out:
#                            Entered Hours_bill  Entered Hours_total  \
# Organization Name
# Africa                                1719.23              2303.25
# Comms & KM                            3156.49              4623.13
# General Intl                           285.14              3655.95
# Global Adaptive Managemen            11382.23             12819.33
# Habitat                               2455.95              3631.66
# Latin America & the Carib             5922.95              6609.16
# Water                                 1853.05              3285.13
#
#                            prop_to_org  weighted_fte  utilization
# Organization Name
# Africa                        0.048589   2448.893056     0.702044
# Comms & KM                    0.097529   4915.467688     0.642155
# General Intl                  0.077126   3887.129303     0.073355
# Global Adaptive Managemen     0.270435  13629.943868     0.835090
# Habitat                       0.076613   3861.303356     0.636042
# Latin America & the Carib     0.139426   7027.081744     0.842875
# Water                         0.069303   3492.860976     0.530525

# %%
# join to single df
hrs_df = pd.merge(org_bill_hrs, org_total_hrs, left_index=True, right_index=True, suffixes=('_bill', '_total'))
hrs_df
# Out:
#                            Entered Hours_bill  Entered Hours_total
# Organization Name
# Africa                                1719.23              2303.25
# Comms & KM                            3156.49              4623.13
# General Intl                           285.14              3655.95
# Global Adaptive Managemen            11382.23             12819.33
# Habitat                               2455.95              3631.66
# Latin America & the Carib             5922.95              6609.16
# Water                                 1853.05              3285.13

# %% [markdown]
# ## Calculations
# ### Proportion to organization
# prop_to_org = org_total_hrs / total_hrs

# %%
# divide org total hrs by total hours to get proportion
hrs_df['prop_to_org'] = hrs_df['Entered Hours_total'] / total_hrs
hrs_df
# Out:
#                            Entered Hours_bill  Entered Hours_total  \
# Organization Name
# Africa                                1719.23              2303.25
# Comms & KM                            3156.49              4623.13
# General Intl                           285.14              3655.95
# Global Adaptive Managemen            11382.23             12819.33
# Habitat                               2455.95              3631.66
# Latin America & the Carib             5922.95              6609.16
# Water                                 1853.05              3285.13
#
#                            prop_to_org
# Organization Name
# Africa                        0.048589
# Comms & KM                    0.097529
# General Intl                  0.077126
# Global Adaptive Managemen     0.270435
# Habitat                       0.076613
# Latin America & the Carib     0.139426
# Water                         0.069303

# %% [markdown]
# ### Weighted FTE
# weighted_fte = prop_to_org * fte_hrs

# %%
# weight fte by prop to org
hrs_df['weighted_fte'] = hrs_df['prop_to_org'] * fte_hrs
hrs_df
# Out:
#                            Entered Hours_bill  Entered Hours_total  \
# Organization Name
# Africa                                1719.23              2303.25
# Comms & KM                            3156.49              4623.13
# General Intl                           285.14              3655.95
# Global Adaptive Managemen            11382.23             12819.33
# Habitat                               2455.95              3631.66
# Latin America & the Carib             5922.95              6609.16
# Water                                 1853.05              3285.13
#
#                            prop_to_org  weighted_fte
# Organization Name
# Africa                        0.048589   2448.893056
# Comms & KM                    0.097529   4915.467688
# General Intl                  0.077126   3887.129303
# Global Adaptive Managemen     0.270435  13629.943868
# Habitat                       0.076613   3861.303356
# Latin America & the Carib     0.139426   7027.081744
# Water                         0.069303   3492.860976

# %% [markdown]
# ### Utilization
# utilization = org_bill_hrs / weighted_fte

# %%
# utilization is billale hours divided by weighted fte
hrs_df['utilization'] = hrs_df['Entered Hours_bill'] / hrs_df['weighted_fte']
hrs_df.to_csv(r'C:\Users\Erik\Downloads\portfolio_utilization.csv')
hrs_df
# Out:
#                            Entered Hours_bill  Entered Hours_total  \
# Organization Name
# Africa                                1719.23              2303.25
# Comms & KM                            3156.49              4623.13
# General Intl                           285.14              3655.95
# Global Adaptive Managemen            11382.23             12819.33
# Habitat                               2455.95              3631.66
# Latin America & the Carib             5922.95              6609.16
# Water                                 1853.05              3285.13
#
#                            prop_to_org  weighted_fte  utilization
# Organization Name
# Africa                        0.048589   2448.893056     0.702044
# Comms & KM                    0.097529   4915.467688     0.642155
# General Intl                  0.077126   3887.129303     0.073355
# Global Adaptive Managemen     0.270435  13629.943868     0.835090
# Habitat                       0.076613   3861.303356     0.636042
# Latin America & the Carib     0.139426   7027.081744     0.842875
# Water                         0.069303   3492.860976     0.530525

# %%
# what proportion of hours went towards billale projects
hrs_df['Entered Hours_bill'].sum() / total_hrs
# Out:
# 0.5648437552739767

# %%
# what was the company-wide utilization?
hrs_df['Entered Hours_bill'].sum() / fte_hrs
# Out:
# 0.5312507936507936

# %% [markdown]
# ## Notes

# %%
# Note that Molly does not appear to be updated in the system
filt = emp_df['Last Name'] == 'Armanino'
emp_df.loc[filt]
# Out:
#    Employee ID Last Name First Name Middle Initial  \
# 4       100027  Armanino      Molly            NaN
#
#                    E-mail Address Active Flag  Hire date Termination date  \
# 4  marmanino@enviroincentives.com           N 2017-06-18       2019-12-14
#
#   Work Schedule Work Schedule Description Default Org
# 4           NaN                       NaN         NaN

# %%
# However she also does not appear to be billing
filt = util_df['Last Name'] == 'Armanino'
util_df.loc[filt]
# Out:
# Empty DataFrame
# Columns: [Employee ID, Last Name, First Name, Work Schedule Description, Org Name, Project ID, Project Name, User Defined Code 3, Hours Date, Entered Hours, Approved Hours, Comments]
# Index: []

# %%
util_df['Last Name'].unique()
# Out:
# array(['Alexandrovich', 'Ajroud', 'Chandrasekaran', 'Cook', 'Dubois',
#        'Flower', 'Gambrill', 'Gibert', 'Hardeman', 'Hicks', 'Hoye',
#        'Lauck', 'Nease', 'Peabody', 'Present', 'Schueler', 'Anderson',
#        'Boysen', 'Motlow', 'Riley', 'Sokulsky', 'Praul', 'Hansen',
#        'Guetschow', 'Brock', 'Chesterman', 'Abragan', 'Uhl', 'Exline',
#        'King', 'Chery', 'Shay', 'Baca', 'Martinez-Sanchez', 'Grange',
#        'Castillo Ferri', 'Nico', 'Wolf', 'Mirghani', 'Motolinia',
#        'Daniels', 'Durand', 'Haik', 'Bevins', 'Wong', 'Sarkisian',
#        'Spencer', 'Ballard', 'Boutemy', 'Schmidt', 'Giannoni', 'Tripp',
#        'Reilly', 'Witz', 'Fong', 'Connolly', 'Masood', 'Peimbert',
#        'Owusu', 'Walter', 'Byenkya', 'Richards', 'Myers', 'Kapikinyu'],
#       dtype=object)

# %%
def calc_period_utilization(df, emp_df, start, end):
    
    def get_bus_hrs(emp_df, start, end):
        """start and end as 'YYYY-MM-DD' strings"""
        start = pd.to_datetime(start)
        end = pd.to_datetime(end)

        fte_df = emp_df[['Employee ID', 'Hire date', 'Termination date']].copy()

        def update_start(hire_date):
            if hire_date < start:
                return start
            elif hire_date > end:
                return end
            else:
                return hire_date

        def update_end(termination_date):
            if pd.isnull(termination_date):
                return end
            if termination_date > end:
                return end
            elif termination_date < start:
                return start
            else:
                return termination_date

        fte_df['sem_start'] = fte_df['Hire date'].apply(update_start)
        fte_df['sem_end'] = fte_df['Termination date'].apply(update_end)
        fte_df['bushrs'] = np.busday_count(fte_df['sem_start'].dt.date, fte_df['sem_end'].dt.date) * 8

        fte_hrs = fte_df['bushrs'].sum()

        return fte_hrs

    
    def get_total_hrs(df, start, end):
        """start and end as 'YYYY-MM-DD' strings"""
        start = pd.to_datetime(start)
        end = pd.to_datetime(end)

        filt = (df['Hours Date'] >= start) & (df['Hours Date'] <= end)
        df = df.loc[filt]

        total_hrs = df['Entered Hours'].sum()

        return total_hrs

    
    def get_org_total_hrs(df, start, end):
        """start and end as 'YYYY-MM-DD' strings
        returns df"""
        start = pd.to_datetime(start)
        end = pd.to_datetime(end)

        filt = (df['Hours Date'] >= start) & (df['Hours Date'] <= end)
        df = df.loc[filt]

        org_total_hrs = df.groupby('Organization Name').sum()['Entered Hours']

        return org_total_hrs

    
    def get_org_bill_hrs(df, start, end):
        """start and end as 'YYYY-MM-DD' strings
        returns df"""
        start = pd.to_datetime(start)
        end = pd.to_datetime(end)

        filt = (df['Hours Date'] >= start) & (df['Hours Date'] <= end)
        df = df.loc[filt]

        filt = df['User Defined Code 3'] == 'SRV'
        org_bill_hrs = df.loc[filt].groupby('Organization Name').sum()['Entered Hours']

        return org_bill_hrs


    def create_hrs_df(org_bill_hrs, org_total_hrs, total_hrs, fte_hrs):
        hrs_df = pd.merge(org_bill_hrs, org_total_hrs, left_index=True, right_index=True, suffixes=('_bill', '_total'))
        # divide org total hrs by total hours to get proportion
        hrs_df['prop_to_org'] = hrs_df['Entered Hours_total'] / total_hrs
        # weight fte by prop to org
        hrs_df['weighted_fte'] = hrs_df['prop_to_org'] * fte_hrs
        # utilization is billale hours divided by weighted fte
        hrs_df['utilization'] = hrs_df['Entered Hours_bill'] / hrs_df['weighted_fte']

        return hrs_df
    
    
    bus_hrs = get_bus_hrs(emp_df, start, end)
    total_hrs = get_total_hrs(df, start, end)
    org_total_hrs = get_org_total_hrs(df, start, end)
    org_bill_hrs = get_org_bill_hrs(df, start, end)
    hrs_df = create_hrs_df(org_bill_hrs, org_total_hrs, total_hrs, bus_hrs)
    print(f'bus_hrs: {bus_hrs}\ntotal_hrs: {total_hrs}\n')
    
    return hrs_df

# %%
june_df = calc_period_utilization(df, emp_df, '2020-06-01', '2020-06-30')
june_df
# Out:
# bus_hrs: 7616
# total_hrs: 7214.98
#                            Entered Hours_bill  Entered Hours_total  \
# Organization Name
# Africa                                 183.78               325.06
# Comms & KM                             701.44              1002.30
# Global Adaptive Managemen             1361.45              1730.11
# Habitat                                331.59               624.45
# Latin America & the Carib              970.83              1052.49
# Water                                  380.20               579.70
#
#                            prop_to_org  weighted_fte  utilization
# Organization Name
# Africa                        0.045053    343.127349     0.535603
# Comms & KM                    0.138919   1058.009419     0.662981
# Global Adaptive Managemen     0.239794   1826.272250     0.745480
# Habitat                       0.086549    659.157919     0.503051
# Latin America & the Carib     0.145876   1110.989059     0.873843
# Water                         0.080347    611.920643     0.621322

# %%
july_df = calc_period_utilization(df, emp_df, '2020-07-01', '2020-07-31')
july_df
# Out:
# bus_hrs: 9568
# total_hrs: 9460.93
#                            Entered Hours_bill  Entered Hours_total  \
# Organization Name
# Africa                                 313.92               392.89
# Comms & KM                             702.33              1004.35
# General Intl                            48.02               772.69
# Global Adaptive Managemen             2523.23              2893.14
# Habitat                                522.27               754.59
# Latin America & the Carib             1082.92              1256.38
# Water                                  506.12               694.16
#
#                            prop_to_org  weighted_fte  utilization
# Organization Name
# Africa                        0.041528    397.336363     0.790061
# Comms & KM                    0.106158   1015.716299     0.691463
# General Intl                  0.081672    781.434586     0.061451
# Global Adaptive Managemen     0.305799   2925.881866     0.862383
# Habitat                       0.079759    763.129747     0.684379
# Latin America & the Carib     0.132797   1270.598539     0.852291
# Water                         0.073371    702.015857     0.720952

# %%
aug_df = calc_period_utilization(df, emp_df, '2020-08-01', '2020-08-31')
aug_df
# Out:
# bus_hrs: 9328
# total_hrs: 9308.0
#                            Entered Hours_bill  Entered Hours_total  \
# Organization Name
# Africa                                 388.80               502.87
# Comms & KM                             587.67               817.53
# General Intl                            75.86               695.44
# Global Adaptive Managemen             2599.13              2785.44
# Habitat                                583.24               783.67
# Latin America & the Carib              948.16              1097.56
# Water                                  392.63               812.19
#
#                            prop_to_org  weighted_fte  utilization
# Organization Name
# Africa                        0.054026    503.950511     0.771504
# Comms & KM                    0.087831    819.286618     0.717295
# General Intl                  0.074714    696.934284     0.108848
# Global Adaptive Managemen     0.299252   2791.425045     0.931112
# Habitat                       0.084193    785.353863     0.742646
# Latin America & the Carib     0.117916   1099.918315     0.862028
# Water                         0.087257    813.935144     0.482385

# %%
sept_df = calc_period_utilization(df, emp_df, '2020-09-01', '2020-09-30')
sept_df
# Out:
# bus_hrs: 10720
# total_hrs: 10814.35
#                            Entered Hours_bill  Entered Hours_total  \
# Organization Name
# Africa                                 411.16               533.49
# Comms & KM                             562.94               985.23
# General Intl                            94.39               650.97
# Global Adaptive Managemen             2555.38              2816.07
# Habitat                                495.04               685.67
# Latin America & the Carib             1398.23              1524.05
# Water                                  299.60               621.48
#
#                            prop_to_org  weighted_fte  utilization
# Organization Name
# Africa                        0.049332    528.835556     0.777482
# Comms & KM                    0.091104    976.634342     0.576408
# General Intl                  0.060195    645.290600     0.146275
# Global Adaptive Managemen     0.260401   2791.501144     0.915414
# Habitat                       0.063404    679.687859     0.728334
# Latin America & the Carib     0.140928   1510.753397     0.925518
# Water                         0.057468    616.057886     0.486318

# %%
oct_df = calc_period_utilization(df, emp_df, '2020-10-01', '2020-10-31')
oct_df
# Out:
# bus_hrs: 11312
# total_hrs: 10308.3
#                            Entered Hours_bill  Entered Hours_total  \
# Organization Name
# Africa                                 421.57               548.94
# Comms & KM                             602.11               813.72
# General Intl                            66.87               703.90
# Global Adaptive Managemen             2343.04              2594.57
# Habitat                                523.81               783.28
# Latin America & the Carib             1522.81              1678.68
# Water                                  274.50               577.60
#
#                            prop_to_org  weighted_fte  utilization
# Organization Name
# Africa                        0.053252    602.389267     0.699830
# Comms & KM                    0.078938    892.950403     0.674293
# General Intl                  0.068285    772.437434     0.086570
# Global Adaptive Managemen     0.251697   2847.198456     0.822928
# Habitat                       0.075985    859.546517     0.609403
# Latin America & the Carib     0.162847   1842.129950     0.826657
# Water                         0.056033    633.839838     0.433075
